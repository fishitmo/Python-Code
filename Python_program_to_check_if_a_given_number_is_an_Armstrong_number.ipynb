# %% [markdown]
# <a href="https://colab.research.google.com/github/fishitmo/Python-Code/blob/main/Python_program_to_check_if_a_given_number_is_an_Armstrong_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# An Armstrong number (also known as narcissistic number) is a number that is equal to the sum of its own digits each raised to the power of the number of digits. Here's a Python program to check if a given number is an Armstrong number:
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
def is_armstrong(number):
    """
    Check if a given number is an Armstrong number.

    :param number: The number to check
    :type number: int
    :return: True if the number is an Armstrong number, False otherwise
    :rtype: bool

    """
    # calcculate the number of digits
    num_digits = len(str(number))

    # compute the sume of digits each raised to the power of num_digits
    sum_of_powers = sum(int(digit) ** num_digits for digit in str(number))

    #check if the number is equal to the sum of powers

    return number == sum_of_powers

# %%
# Example usage

number = int(input("Entere a number to check if it's an Armstrong number: "))
if is_armstrong(number):
  print(number, "is an Armstrong number")
else:
  print(number, "is not an Armstrong number")
# Out:
# Entere a number to check if it's an Armstrong number: 153
# 153 is an Armstrong number
